# %%
import matplotlib.pylab as pl
# %matplotlib inline
# from sklearn.manifold import TSNE
from tsnecuda import TSNE

# %%
# %run -i poc.py --alpha 1e-1 --p-train 0.1
# Out:
# 9.992e-02 | 9.992e-02 | 9.992e-02

# %%
u = TSNE(verbose=1).fit_transform(h_item)
pl.plot(u[:, 0], u[:, 1], 'bo')

# %%
for i in range(args.n_ctgrs):
    j = i * args.n_items_per_ctgr
    k = (i + 1) * args.n_items_per_ctgr
    pl.plot(u[j : k, 0], u[j : k, 1], 'o', label=str(i))

# %%
# %run -i poc.py --alpha 1e-1 --p-train 0.1 --temporal
# Out:
# 1.000e-01 | 6.400e-01 | 6.408e-01
# 1.774e-01 | 1.779e-01 | 1.780e-01

# %%
# %run -i poc.py --alpha 1e-1 --n-factors {args.n_factors // args.n_sesses} --p-train 0.1 --temporal
# Out:
# 1.000e-01 | 6.409e-01 | 6.414e-01
# 1.153e-01 | 1.158e-01 | 1.158e-01

# %%
u = TSNE(verbose=1).fit_transform(np.squeeze(h_item))
pl.plot(u[:, 0], u[:, 1], 'bo')

# %%
for i in range(args.n_ctgrs):
    j = i * args.n_items_per_ctgr
    k = (i + 1) * args.n_items_per_ctgr
    pl.plot(u[j : k, 0], u[j : k, 1], 'o', label=str(i))
